# %% [markdown]
# ## Introduction:
# Effective waste recycling is both economic and environmentally beneficial. It can help in recovering raw resources, preserving energy, mitigating greenhouse gaseous emission, water pollution, reducing new landfills. For that reason, we decide to use deep learning for building a classification system the waste item as either recyclable or not.
#
# ## objective
#
# we will train a convolutional neural network to classify an image as either cardboard, glass, metal, paper, plastic, or trash with the fastai library (built on PyTorch).
#
# ## steps
#
# 1. Download and extract the images
# 2. Organize the images into different folders
# 3. Train the model
# 4. save the model
# 5. Make and evaluate test predictions
# 6. export the model
# 7. load and test it from real pictures!

# %%
import fastai;

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %config InlineBackend.figure_format = 'retina'

# %%
from fastai.vision import *
import sklearn
from fastai.metrics import error_rate
from pathlib import Path
from glob2 import glob
from sklearn.metrics import confusion_matrix

import pandas as pd
import numpy as np
import os
import zipfile as zf
import shutil
import re
import seaborn as sns
import pickle

# %% [markdown]
# ## 1. Extract data

# %%
files = zf.ZipFile("/content/drive/MyDrive/Recycle_Classification/dataset-resized.zip",'r')
files.extractall()
files.close()

# %%
os.listdir(os.path.join(os.getcwd(),"dataset-resized"))
# Out:
# ['trash', 'cardboard', 'paper', 'metal', 'glass', '.DS_Store', 'plastic']

# %% [markdown]
# ## 2. Organize images into different folders
#  split images into train, validation, and test image folders with a 50-25-25 split.

# %%
## helper functions ##

## splits indices for a folder into train, validation, and test indices with random sampling
    ## input: folder path
    ## output: train, valid, and test indices    
def split_indices(folder,seed1,seed2):    
    n = len(os.listdir(folder))
    full_set = list(range(1,n+1))

    ## train indices
    random.seed(seed1)
    train = random.sample(list(range(1,n+1)),int(.5*n))

    ## temp
    remain = list(set(full_set)-set(train))

    ## separate remaining into validation and test
    random.seed(seed2)
    valid = random.sample(remain,int(.5*len(remain)))
    test = list(set(remain)-set(valid))
    
    return(train,valid,test)

## gets file names for a particular type of trash, given indices
    ## input: waste category and indices
    ## output: file names 
def get_names(waste_type,indices):
    file_names = [waste_type+str(i)+".jpg" for i in indices]
    return(file_names)    

## moves group of source files to another folder
    ## input: list of source files and destination folder
    ## no output
def move_files(source_files,destination_folder):
    for file in source_files:
        shutil.move(file,destination_folder)

# %% [markdown]
# ImageNet directory convention. It'll look like this:
#
# /data <br>
# &nbsp;&nbsp;&nbsp;&nbsp; /train <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;    /cardboard <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;    /glass <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;    /metal <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;    /paper <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;    /plastic <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;    /trash <br>
# &nbsp;&nbsp;&nbsp;&nbsp; /valid <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;    /cardboard <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;    /glass <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;    /metal <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;    /paper <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;    /plastic <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;    /trash <br>
# &nbsp;&nbsp;&nbsp;&nbsp;/test <br>
#
# Each image file is just the material name and a number (i.e. cardboard1.jpg)

# %%
## paths will be train/cardboard, train/glass, etc...
subsets = ['train','valid']
waste_types = ['cardboard','glass','metal','paper','plastic','trash']

## create destination folders for data subset and waste type
for subset in subsets:
    for waste_type in waste_types:
        folder = os.path.join('data',subset,waste_type)
        if not os.path.exists(folder):
            os.makedirs(folder)
            
if not os.path.exists(os.path.join('data','test')):
    os.makedirs(os.path.join('data','test'))
            
## move files to destination folders for each waste type
for waste_type in waste_types:
    source_folder = os.path.join('dataset-resized',waste_type)
    train_ind, valid_ind, test_ind = split_indices(source_folder,1,1)
    
    ## move source files to train
    train_names = get_names(waste_type,train_ind)
    train_source_files = [os.path.join(source_folder,name) for name in train_names]
    train_dest = "data/train/"+waste_type
    move_files(train_source_files,train_dest)
    
    ## move source files to valid
    valid_names = get_names(waste_type,valid_ind)
    valid_source_files = [os.path.join(source_folder,name) for name in valid_names]
    valid_dest = "data/valid/"+waste_type
    move_files(valid_source_files,valid_dest)
    
    ## move source files to test
    test_names = get_names(waste_type,test_ind)
    test_source_files = [os.path.join(source_folder,name) for name in test_names]
    ## I use data/test here because the images can be mixed up
    move_files(test_source_files,"data/test")

# %%
## get a path to the folder with images
path = Path(os.getcwd())/"data"
path
# Out:
# PosixPath('/content/data')

# %%
tfms = get_transforms(do_flip=True,flip_vert=True)
data = ImageDataBunch.from_folder(path,test="test",ds_tfms=tfms,bs=16)

# %% [markdown]
# The batch size bs is how many images you'll train at a time.

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (1262 items)
# x: ImageList
# Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512)
# y: CategoryList
# trash,trash,trash,trash,trash
# Path: /content/data;
#
# Valid: LabelList (630 items)
# x: ImageList
# Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512)
# y: CategoryList
# trash,trash,trash,trash,trash
# Path: /content/data;
#
# Test: LabelList (635 items)
# x: ImageList
# Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512)
# y: EmptyLabelList
# ,,,,
# Path: /content/data

# %%
print(data.classes)
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %% [markdown]
# Here's an example of what the data looks like:

# %%
data.show_batch(rows=4,figsize=(10,8))

# %% [markdown]
# ## 3. Model training

# %%
learn = cnn_learner(data,models.resnet34,metrics=accuracy)

# %%
learn.summary()
# Out:
# Sequential
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# Conv2d               [64, 192, 256]       9,408      False
# ______________________________________________________________________
# BatchNorm2d          [64, 192, 256]       128        True
# ______________________________________________________________________
# ReLU                 [64, 192, 256]       0          False
# ______________________________________________________________________
# MaxPool2d            [64, 96, 128]        0          False
# ______________________________________________________________________
# Conv2d               [64, 96, 128]        36,864     False
# ______________________________________________________________________
# BatchNorm2d          [64, 96, 128]        128        True
# ______________________________________________________________________
# ReLU                 [64, 96, 128]        0          False
# ______________________________________________________________________
# Conv2d               [64, 96, 128]        36,864     False
# ______________________________________________________________________
# BatchNorm2d          [64, 96, 128]        128        True
# ______________________________________________________________________
# Conv2d               [64, 96, 128]        36,864     False
# ______________________________________________________________________
# BatchNorm2d          [64, 96, 128]        128        True
# ______________________________________________________________________
# ReLU                 [64, 96, 128]        0          False
# ______________________________________________________________________
# Conv2d               [64, 96, 128]        36,864     False
# ______________________________________________________________________
# BatchNorm2d          [64, 96, 128]        128        True
# ______________________________________________________________________
# Conv2d               [64, 96, 128]        36,864     False
# ______________________________________________________________________
# BatchNorm2d          [64, 96, 128]        128        True
# ______________________________________________________________________
# ReLU                 [64, 96, 128]        0          False
# ______________________________________________________________________
# Conv2d               [64, 96, 128]        36,864     False
# ______________________________________________________________________
# BatchNorm2d          [64, 96, 128]        128        True
# ______________________________________________________________________
# Conv2d               [128, 48, 64]        73,728     False
# ______________________________________________________________________
# BatchNorm2d          [128, 48, 64]        256        True
# ______________________________________________________________________
# ReLU                 [128, 48, 64]        0          False
# ______________________________________________________________________
# Conv2d               [128, 48, 64]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 48, 64]        256        True
# ______________________________________________________________________
# Conv2d               [128, 48, 64]        8,192      False
# ______________________________________________________________________
# BatchNorm2d          [128, 48, 64]        256        True
# ______________________________________________________________________
# Conv2d               [128, 48, 64]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 48, 64]        256        True
# ______________________________________________________________________
# ReLU                 [128, 48, 64]        0          False
# ______________________________________________________________________
# Conv2d               [128, 48, 64]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 48, 64]        256        True
# ______________________________________________________________________
# Conv2d               [128, 48, 64]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 48, 64]        256        True
# ______________________________________________________________________
# ReLU                 [128, 48, 64]        0          False
# ______________________________________________________________________
# Conv2d               [128, 48, 64]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 48, 64]        256        True
# ______________________________________________________________________
# Conv2d               [128, 48, 64]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 48, 64]        256        True
# ______________________________________________________________________
# ReLU                 [128, 48, 64]        0          False
# ______________________________________________________________________
# Conv2d               [128, 48, 64]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 48, 64]        256        True
# ______________________________________________________________________
# Conv2d               [256, 24, 32]        294,912    False
# ______________________________________________________________________
# BatchNorm2d          [256, 24, 32]        512        True
# ______________________________________________________________________
# ReLU                 [256, 24, 32]        0          False
# ______________________________________________________________________
# Conv2d               [256, 24, 32]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 24, 32]        512        True
# ______________________________________________________________________
# Conv2d               [256, 24, 32]        32,768     False
# ______________________________________________________________________
# BatchNorm2d          [256, 24, 32]        512        True
# ______________________________________________________________________
# Conv2d               [256, 24, 32]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 24, 32]        512        True
# ______________________________________________________________________
# ReLU                 [256, 24, 32]        0          False
# ______________________________________________________________________
# Conv2d               [256, 24, 32]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 24, 32]        512        True
# ______________________________________________________________________
# Conv2d               [256, 24, 32]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 24, 32]        512        True
# ______________________________________________________________________
# ReLU                 [256, 24, 32]        0          False
# ______________________________________________________________________
# Conv2d               [256, 24, 32]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 24, 32]        512        True
# ______________________________________________________________________
# Conv2d               [256, 24, 32]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 24, 32]        512        True
# ______________________________________________________________________
# ReLU                 [256, 24, 32]        0          False
# ______________________________________________________________________
# Conv2d               [256, 24, 32]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 24, 32]        512        True
# ______________________________________________________________________
# Conv2d               [256, 24, 32]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 24, 32]        512        True
# ______________________________________________________________________
# ReLU                 [256, 24, 32]        0          False
# ______________________________________________________________________
# Conv2d               [256, 24, 32]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 24, 32]        512        True
# ______________________________________________________________________
# Conv2d               [256, 24, 32]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 24, 32]        512        True
# ______________________________________________________________________
# ReLU                 [256, 24, 32]        0          False
# ______________________________________________________________________
# Conv2d               [256, 24, 32]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 24, 32]        512        True
# ______________________________________________________________________
# Conv2d               [512, 12, 16]        1,179,648  False
# ______________________________________________________________________
# BatchNorm2d          [512, 12, 16]        1,024      True
# ______________________________________________________________________
# ReLU                 [512, 12, 16]        0          False
# ______________________________________________________________________
# Conv2d               [512, 12, 16]        2,359,296  False
# ______________________________________________________________________
# BatchNorm2d          [512, 12, 16]        1,024      True
# ______________________________________________________________________
# Conv2d               [512, 12, 16]        131,072    False
# ______________________________________________________________________
# BatchNorm2d          [512, 12, 16]        1,024      True
# ______________________________________________________________________
# Conv2d               [512, 12, 16]        2,359,296  False
# ______________________________________________________________________
# BatchNorm2d          [512, 12, 16]        1,024      True
# ______________________________________________________________________
# ReLU                 [512, 12, 16]        0          False
# ______________________________________________________________________
# Conv2d               [512, 12, 16]        2,359,296  False
# ______________________________________________________________________
# BatchNorm2d          [512, 12, 16]        1,024      True
# ______________________________________________________________________
# Conv2d               [512, 12, 16]        2,359,296  False
# ______________________________________________________________________
# BatchNorm2d          [512, 12, 16]        1,024      True
# ______________________________________________________________________
# ReLU                 [512, 12, 16]        0          False
# ______________________________________________________________________
# Conv2d               [512, 12, 16]        2,359,296  False
# ______________________________________________________________________
# BatchNorm2d          [512, 12, 16]        1,024      True
# ______________________________________________________________________
# AdaptiveAvgPool2d    [512, 1, 1]          0          False
# ______________________________________________________________________
# AdaptiveMaxPool2d    [512, 1, 1]          0          False
# ______________________________________________________________________
# Flatten              [1024]               0          False
# ______________________________________________________________________
# BatchNorm1d          [1024]               2,048      True
# ______________________________________________________________________
# Dropout              [1024]               0          False
# ______________________________________________________________________
# Linear               [512]                524,800    True
# ______________________________________________________________________
# ReLU                 [512]                0          False
# ______________________________________________________________________
# BatchNorm1d          [512]                1,024      True
# ______________________________________________________________________
# Dropout              [512]                0          False
# ______________________________________________________________________
# Linear               [6]                  3,078      True
# ______________________________________________________________________
#
# Total params: 21,815,622
# Total trainable params: 547,974
# Total non-trainable params: 21,267,648
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : FlattenedLoss
# ======================================================================
# Callbacks functions applied

# %% [markdown]
# ### Finding a learning rate
#
# find a learning rate for gradient descent to make sure that neural network converges reasonably quickly without missing the optimal error.

# %%
learn.lr_find(start_lr=1e-6,end_lr=1e1)
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [1/2 00:39<00:39]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.161479</td>
#       <td>#na#</td>
#       <td>00:39</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='7' class='' max='78' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       8.97% [7/78 00:04<00:43 7.7681]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot(suggestion=True)
# Out:
# Min numerical gradient: 7.41E-04
# Min loss divided by 10: 1.58E-03

# %%
min_grad_lr = learn.recorder.min_grad_lr
min_grad_lr
# Out:
# 0.0007413102413009172

# %% [markdown]
# ### Training

# %%
learn.fit_one_cycle(50,min_grad_lr)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.827735</td>
#       <td>1.737947</td>
#       <td>0.322222</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.266264</td>
#       <td>1.225056</td>
#       <td>0.519048</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.790714</td>
#       <td>0.893942</td>
#       <td>0.671429</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.466397</td>
#       <td>0.692746</td>
#       <td>0.753968</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.165009</td>
#       <td>0.558018</td>
#       <td>0.803175</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.994588</td>
#       <td>0.488020</td>
#       <td>0.831746</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.826029</td>
#       <td>0.428218</td>
#       <td>0.847619</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.722951</td>
#       <td>0.417254</td>
#       <td>0.863492</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.691052</td>
#       <td>0.391816</td>
#       <td>0.871429</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.654872</td>
#       <td>0.411204</td>
#       <td>0.866667</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.576106</td>
#       <td>0.391338</td>
#       <td>0.885714</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.515551</td>
#       <td>0.355568</td>
#       <td>0.895238</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.489541</td>
#       <td>0.398434</td>
#       <td>0.895238</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.477352</td>
#       <td>0.321843</td>
#       <td>0.914286</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.411204</td>
#       <td>0.344694</td>
#       <td>0.885714</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.411023</td>
#       <td>0.308358</td>
#       <td>0.904762</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.406172</td>
#       <td>0.306220</td>
#       <td>0.915873</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.355215</td>
#       <td>0.284597</td>
#       <td>0.909524</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.343033</td>
#       <td>0.284059</td>
#       <td>0.906349</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.328104</td>
#       <td>0.287233</td>
#       <td>0.919048</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.311179</td>
#       <td>0.296662</td>
#       <td>0.914286</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.281488</td>
#       <td>0.281628</td>
#       <td>0.926984</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.265060</td>
#       <td>0.278020</td>
#       <td>0.920635</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.275995</td>
#       <td>0.287560</td>
#       <td>0.914286</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.217504</td>
#       <td>0.276116</td>
#       <td>0.926984</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.227828</td>
#       <td>0.252345</td>
#       <td>0.923810</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.230061</td>
#       <td>0.252092</td>
#       <td>0.931746</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.224087</td>
#       <td>0.271678</td>
#       <td>0.925397</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.178867</td>
#       <td>0.261068</td>
#       <td>0.925397</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.195181</td>
#       <td>0.221615</td>
#       <td>0.934921</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.213819</td>
#       <td>0.241081</td>
#       <td>0.930159</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.155366</td>
#       <td>0.226394</td>
#       <td>0.934921</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.177131</td>
#       <td>0.251734</td>
#       <td>0.928571</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.172975</td>
#       <td>0.227003</td>
#       <td>0.931746</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.144713</td>
#       <td>0.258361</td>
#       <td>0.931746</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.124403</td>
#       <td>0.248507</td>
#       <td>0.930159</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.129236</td>
#       <td>0.234617</td>
#       <td>0.938095</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.135619</td>
#       <td>0.216298</td>
#       <td>0.939683</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.133154</td>
#       <td>0.233849</td>
#       <td>0.931746</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.111370</td>
#       <td>0.221363</td>
#       <td>0.938095</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.150434</td>
#       <td>0.234102</td>
#       <td>0.938095</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.133765</td>
#       <td>0.243788</td>
#       <td>0.936508</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.115303</td>
#       <td>0.226854</td>
#       <td>0.942857</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.109712</td>
#       <td>0.222791</td>
#       <td>0.941270</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.122696</td>
#       <td>0.235712</td>
#       <td>0.939683</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.104337</td>
#       <td>0.226776</td>
#       <td>0.944444</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.114236</td>
#       <td>0.230379</td>
#       <td>0.941270</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.100093</td>
#       <td>0.228027</td>
#       <td>0.944444</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.081189</td>
#       <td>0.229713</td>
#       <td>0.939683</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.095714</td>
#       <td>0.231893</td>
#       <td>0.938095</td>
#       <td>00:47</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # 4.save model

# %%
learn.save("/content/drive/MyDrive/Recycle_Classification/modelAfterTrainResNet34")

# %% [markdown]
# ### VIsualizing most incorrect images

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
doc(interp.plot_top_losses)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)
# Out:
# <h4 id="_cl_int_plot_top_losses" class="doc_header"><code>_cl_int_plot_top_losses</code><a href="https://github.com/fastai/fastai/blob/master/fastai/vision/learner.py#L166" class="source_link" style="float:right">[source]</a><a class="source_link" data-toggle="collapse" data-target="#_cl_int_plot_top_losses-pytest" style="float:right; padding-right:10px">[test]</a></h4><blockquote><p><code>_cl_int_plot_top_losses</code>(<strong><code>k</code></strong>, <strong><code>largest</code></strong>=<strong><em><code>True</code></em></strong>, <strong><code>figsize</code></strong>=<strong><em><code>(12, 12)</code></em></strong>, <strong><code>heatmap</code></strong>:<code>bool</code>=<strong><em><code>False</code></em></strong>, <strong><code>heatmap_thresh</code></strong>:<code>int</code>=<strong><em><code>16</code></em></strong>, <strong><code>alpha</code></strong>:<code>float</code>=<strong><em><code>0.6</code></em></strong>, <strong><code>cmap</code></strong>:<code>str</code>=<strong><em><code>'magma'</code></em></strong>, <strong><code>show_text</code></strong>:<code>bool</code>=<strong><em><code>True</code></em></strong>, <strong><code>return_fig</code></strong>:<code>bool</code>=<strong><em><code>None</code></em></strong>) → <code>Optional</code>[<code>Figure</code>]</p>
# </blockquote>
# <div class="collapse" id="_cl_int_plot_top_losses-pytest"><div class="card card-body pytest_card"><a type="button" data-toggle="collapse" data-target="#_cl_int_plot_top_losses-pytest" class="close" aria-label="Close"><span aria-hidden="true">&times;</span></a><p>No tests found for <code>_cl_int_plot_top_losses</code>. To contribute a test please refer to <a href="/dev/test.html">this guide</a> and <a href="https://forums.fast.ai/t/improving-expanding-functional-tests/32929">this discussion</a>.</p></div></div><p>Show images in <code>top_losses</code> along with their prediction, actual, loss, and probability of actual class.</p>
# <p><a href="https://docs.fast.ai/vision.learner.html#_cl_int_plot_top_losses" target="_blank" rel="noreferrer noopener">Show in docs</a></p>

# %% [markdown]
# This model often confused cardboard for paper and confused glass for plastic.

# %%
interp.most_confused(min_val=2)
# Out:
# [('cardboard', 'paper', 7),
#  ('glass', 'plastic', 6),
#  ('glass', 'metal', 5),
#  ('plastic', 'metal', 5),
#  ('plastic', 'paper', 5),
#  ('metal', 'plastic', 2),
#  ('paper', 'trash', 2),
#  ('plastic', 'trash', 2),
#  ('trash', 'paper', 2)]

# %% [markdown]
# ## 5. Make new predictions on test data

# %%
preds = learn.get_preds(ds_type=DatasetType.Test)

# %%
print(preds[0].shape)
preds[0]
# Out:
# torch.Size([635, 6])
# tensor([[3.0492e-06, 2.4668e-01, 1.2923e-04, 7.0520e-03, 7.4359e-01, 2.5480e-03],
#         [3.5593e-06, 5.0305e-03, 9.9467e-01, 7.3224e-05, 1.8687e-04, 3.2499e-05],
#         [3.6850e-05, 1.0675e-03, 9.4080e-01, 6.7372e-03, 3.9788e-02, 1.1568e-02],
#         ...,
#         [7.3440e-07, 9.7902e-04, 1.1358e-05, 1.0429e-08, 9.9895e-01, 5.5979e-05],
#         [2.9319e-07, 2.9457e-03, 3.6261e-05, 2.6183e-08, 9.9701e-01, 5.2071e-06],
#         [3.0664e-06, 2.2021e-09, 1.4337e-08, 9.9999e-01, 6.0009e-07, 9.9973e-06]])

# %%
data.classes
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %% [markdown]
# convert the probabilities in the tensor above to a string with one of the class names.

# %%
## saves the index (0 to 5) of most likely (max) predicted class for each image
max_idxs = np.asarray(np.argmax(preds[0],axis=1))

# %%
yhat = []
for max_idx in max_idxs:
    yhat.append(data.classes[max_idx])

# %%
yhat
# Out:
# ['plastic',
#  'metal',
#  'metal',
#  'paper',
#  'glass',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'trash',
#  'metal',
#  'glass',
#  'metal',
#  'glass',
#  'cardboard',
#  'plastic',
#  'cardboard',
#  'paper',
#  'trash',
#  'glass',
#  'plastic',
#  'glass',
#  'glass',
#  'plastic',
#  'paper',
#  'paper',
#  'plastic',
#  'trash',
#  'glass',
#  'cardboard',
#  'paper',
#  'glass',
#  'cardboard',
#  'paper',
#  'paper',
#  'metal',
#  'plastic',
#  'paper',
#  'paper',
#  'cardboard',
#  'plastic',
#  'paper',
#  'glass',
#  'plastic',
#  'cardboard',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'glass',
#  'plastic',
#  'plastic',
#  'paper',
#  'trash',
#  'paper',
#  'cardboard',
#  'plastic',
#  'paper',
#  'cardboard',
#  'paper',
#  'glass',
#  'paper',
#  'trash',
#  'paper',
#  'glass',
#  'cardboard',
#  'metal',
#  'paper',
#  'cardboard',
#  'glass',
#  'metal',
#  'paper',
#  'plastic',
#  'metal',
#  'trash',
#  'plastic',
#  'trash',
#  'paper',
#  'glass',
#  'metal',
#  'paper',
#  'paper',
#  'trash',
#  'cardboard',
#  'glass',
#  'plastic',
#  'paper',
#  'glass',
#  'glass',
#  'glass',
#  'paper',
#  'glass',
#  'glass',
#  'plastic',
#  'paper',
#  'trash',
#  'plastic',
#  'paper',
#  'paper',
#  'glass',
#  'plastic',
#  'glass',
#  'paper',
#  'plastic',
#  'cardboard',
#  'paper',
#  'paper',
#  'plastic',
#  'paper',
#  'plastic',
#  'paper',
#  'trash',
#  'paper',
#  'cardboard',
#  'glass',
#  'metal',
#  'paper',
#  'glass',
#  'paper',
#  'cardboard',
#  'glass',
#  'plastic',
#  'paper',
#  'cardboard',
#  'trash',
#  'metal',
#  'paper',
#  'cardboard',
#  'metal',
#  'metal',
#  'cardboard',
#  'metal',
#  'trash',
#  'glass',
#  'plastic',
#  'glass',
#  'metal',
#  'cardboard',
#  'glass',
#  'metal',
#  'glass',
#  'paper',
#  'paper',
#  'metal',
#  'metal',
#  'paper',
#  'cardboard',
#  'paper',
#  'plastic',
#  'paper',
#  'metal',
#  'metal',
#  'glass',
#  'metal',
#  'glass',
#  'paper',
#  'glass',
#  'cardboard',
#  'plastic',
#  'metal',
#  'metal',
#  'glass',
#  'paper',
#  'cardboard',
#  'plastic',
#  'glass',
#  'cardboard',
#  'glass',
#  'paper',
#  'paper',
#  'paper',
#  'paper',
#  'cardboard',
#  'plastic',
#  'paper',
#  'paper',
#  'metal',
#  'metal',
#  'metal',
#  'plastic',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'paper',
#  'glass',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'glass',
#  'metal',
#  'glass',
#  'paper',
#  'glass',
#  'paper',
#  'metal',
#  'metal',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'glass',
#  'plastic',
#  'paper',
#  'metal',
#  'metal',
#  'paper',
#  'metal',
#  'trash',
#  'metal',
#  'paper',
#  'paper',
#  'glass',
#  'cardboard',
#  'metal',
#  'plastic',
#  'cardboard',
#  'metal',
#  'glass',
#  'glass',
#  'plastic',
#  'metal',
#  'trash',
#  'metal',
#  'glass',
#  'cardboard',
#  'paper',
#  'paper',
#  'paper',
#  'paper',
#  'cardboard',
#  'metal',
#  'glass',
#  'cardboard',
#  'glass',
#  'metal',
#  'plastic',
#  'paper',
#  'metal',
#  'paper',
#  'paper',
#  'plastic',
#  'metal',
#  'plastic',
#  'cardboard',
#  'trash',
#  'paper',
#  'glass',
#  'glass',
#  'metal',
#  'trash',
#  'cardboard',
#  'paper',
#  'glass',
#  'glass',
#  'glass',
#  'cardboard',
#  'plastic',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'trash',
#  'cardboard',
#  'trash',
#  'paper',
#  'cardboard',
#  'glass',
#  'plastic',
#  'plastic',
#  'metal',
#  'cardboard',
#  'paper',
#  'glass',
#  'glass',
#  'trash',
#  'cardboard',
#  'paper',
#  'glass',
#  'glass',
#  'glass',
#  'cardboard',
#  'paper',
#  'plastic',
#  'metal',
#  'paper',
#  'metal',
#  'paper',
#  'paper',
#  'plastic',
#  'metal',
#  'cardboard',
#  'plastic',
#  'metal',
#  'paper',
#  'paper',
#  'plastic',
#  'plastic',
#  'glass',
#  'plastic',
#  'trash',
#  'paper',
#  'plastic',
#  'plastic',
#  'plastic',
#  'glass',
#  'metal',
#  'plastic',
#  'plastic',
#  'metal',
#  'cardboard',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'metal',
#  'plastic',
#  'cardboard',
#  'metal',
#  'trash',
#  'glass',
#  'cardboard',
#  'plastic',
#  'glass',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'paper',
#  'glass',
#  'paper',
#  'metal',
#  'paper',
#  'metal',
#  'plastic',
#  'metal',
#  'plastic',
#  'paper',
#  'metal',
#  'glass',
#  'metal',
#  'cardboard',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'trash',
#  'trash',
#  'glass',
#  'paper',
#  'cardboard',
#  'glass',
#  'paper',
#  'metal',
#  'metal',
#  'paper',
#  'metal',
#  'plastic',
#  'trash',
#  'cardboard',
#  'glass',
#  'paper',
#  'metal',
#  'cardboard',
#  'glass',
#  'glass',
#  'glass',
#  'glass',
#  'metal',
#  'plastic',
#  'metal',
#  'paper',
#  'metal',
#  'glass',
#  'plastic',
#  'metal',
#  'metal',
#  'paper',
#  'paper',
#  'plastic',
#  'plastic',
#  'glass',
#  'paper',
#  'plastic',
#  'metal',
#  'paper',
#  'glass',
#  'paper',
#  'paper',
#  'metal',
#  'trash',
#  'plastic',
#  'paper',
#  'paper',
#  'plastic',
#  'plastic',
#  'glass',
#  'plastic',
#  'trash',
#  'cardboard',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'paper',
#  'paper',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'glass',
#  'paper',
#  'metal',
#  'glass',
#  'cardboard',
#  'glass',
#  'metal',
#  'paper',
#  'cardboard',
#  'glass',
#  'plastic',
#  'plastic',
#  'metal',
#  'cardboard',
#  'glass',
#  'paper',
#  'metal',
#  'glass',
#  'cardboard',
#  'paper',
#  'trash',
#  'metal',
#  'metal',
#  'plastic',
#  'metal',
#  'paper',
#  'paper',
#  'trash',
#  'cardboard',
#  'plastic',
#  'paper',
#  'trash',
#  'plastic',
#  'plastic',
#  'paper',
#  'glass',
#  'glass',
#  'paper',
#  'cardboard',
#  'glass',
#  'plastic',
#  'paper',
#  'metal',
#  'glass',
#  'plastic',
#  'plastic',
#  'glass',
#  'plastic',
#  'metal',
#  'cardboard',
#  'glass',
#  'paper',
#  'metal',
#  'paper',
#  'glass',
#  'paper',
#  'cardboard',
#  'plastic',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'glass',
#  'glass',
#  'plastic',
#  'paper',
#  'plastic',
#  'paper',
#  'plastic',
#  'paper',
#  'glass',
#  'plastic',
#  'metal',
#  'paper',
#  'glass',
#  'cardboard',
#  'paper',
#  'metal',
#  'cardboard',
#  'plastic',
#  'paper',
#  'paper',
#  'paper',
#  'metal',
#  'glass',
#  'cardboard',
#  'glass',
#  'plastic',
#  'paper',
#  'glass',
#  'glass',
#  'metal',
#  'plastic',
#  'paper',
#  'paper',
#  'plastic',
#  'metal',
#  'cardboard',
#  'trash',
#  'paper',
#  'paper',
#  'paper',
#  'paper',
#  'plastic',
#  'plastic',
#  'metal',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'cardboard',
#  'cardboard',
#  'cardboard',
#  'paper',
#  'glass',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'paper',
#  'paper',
#  'metal',
#  'plastic',
#  'metal',
#  'glass',
#  'trash',
#  'cardboard',
#  'trash',
#  'paper',
#  'metal',
#  'plastic',
#  'metal',
#  'plastic',
#  'glass',
#  'glass',
#  'metal',
#  'glass',
#  'metal',
#  'trash',
#  'cardboard',
#  'metal',
#  'glass',
#  'glass',
#  'metal',
#  'metal',
#  'metal',
#  'metal',
#  'glass',
#  'plastic',
#  'paper',
#  'metal',
#  'paper',
#  'glass',
#  'paper',
#  'plastic',
#  'metal',
#  'paper',
#  'paper',
#  'paper',
#  'glass',
#  'paper',
#  'plastic',
#  'plastic',
#  'metal',
#  'glass',
#  'paper',
#  'paper',
#  'cardboard',
#  'glass',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'glass',
#  'cardboard',
#  'glass',
#  'plastic',
#  'metal',
#  'paper',
#  'plastic',
#  'paper',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'paper',
#  'plastic',
#  'cardboard',
#  'glass',
#  'glass',
#  'glass',
#  'plastic',
#  'metal',
#  'trash',
#  'paper',
#  'paper',
#  'paper',
#  'glass',
#  'plastic',
#  'paper',
#  'paper',
#  'cardboard',
#  'glass',
#  'paper',
#  'plastic',
#  'trash',
#  'plastic',
#  'metal',
#  'plastic',
#  'paper',
#  'paper',
#  'paper',
#  'paper',
#  'plastic',
#  'cardboard',
#  'paper',
#  'paper',
#  'cardboard',
#  'metal',
#  'glass',
#  'glass',
#  'metal',
#  'paper',
#  'cardboard',
#  'plastic',
#  'cardboard',
#  'glass',
#  'metal',
#  'plastic',
#  'cardboard',
#  'metal',
#  'glass',
#  'plastic',
#  'plastic',
#  'plastic',
#  'paper']

# %% [markdown]
# These are the predicted labels of all the images! Let's check if the first image is actually plastic.

# %%
learn.data.test_ds[0][0]
# Out:
# Image (3, 384, 512)

# %% [markdown]
# it is

# %%
learn.data.test_ds[2][0]
# Out:
# Image (3, 384, 512)

# %% [markdown]
# it is

# %% [markdown]
# Next, get the actual labels from the test dataset.

# %%
y = []

## convert POSIX paths to string first
for label_path in data.test_ds.items:
    y.append(str(label_path))
    
## then extract waste type from file path
pattern = re.compile("([a-z]+)[0-9]+")
for i in range(len(y)):
    y[i] = pattern.search(y[i]).group(1)

# %% [markdown]
# A quick check.

# %%
## predicted values
print(yhat[0:10])
## actual values
print(y[0:10])
# Out:
# ['plastic', 'metal', 'metal', 'paper', 'glass', 'cardboard', 'plastic', 'plastic', 'trash', 'metal']
# ['plastic', 'metal', 'metal', 'paper', 'glass', 'cardboard', 'plastic', 'plastic', 'trash', 'metal']

# %% [markdown]
# It looks the first 10 predictions match up! (check)
#
#
# ### Test confusion matrix

# %%
cm = confusion_matrix(y,yhat)
print(cm)
# Out:
# [[ 95   0   2   4   0   0]
#  [  0 111   6   1   8   0]
#  [  0   4  98   0   0   1]
#  [  0   0   0 146   0   3]
#  [  0   3   0   1 114   3]
#  [  1   0   1   4   1  28]]

# %% [markdown]
#  make this matrix a little prettier.

# %%
df_cm = pd.DataFrame(cm,waste_types,waste_types)

plt.figure(figsize=(10,8))
sns.heatmap(df_cm,annot=True,fmt="d",cmap="YlGnBu")

# %% [markdown]
# Again, the model seems to have ccardboard for paper and confused glass for plastic.

# %%
correct = 0

for r in range(len(cm)):
    for c in range(len(cm)):
        if (r==c):
            correct += cm[r,c]

# %%
accuracy = correct/sum(sum(cm))
accuracy
# Out:
# 0.9322834645669291

# %%
## delete everything when you're done to save space
#shutil.rmtree("data")

#shutil.rmtree('dataset-resized')

# %% [markdown]
# ## 6.export the model

# %%
learn.export('/content/drive/MyDrive/Recycle_Classification/ModelResNet34.pkl')

# %% [markdown]
# ## 7.upload the model and test it

# %%
learnModel = load_learner('/content/drive/MyDrive/Recycle_Classification/','ModelResNet34.pkl')

# %%
#learnModel

# %%
import cv2
from fastai.vision import *
img_cv2 = cv2.imread('/content/drive/MyDrive/Recycle_Classification/TestImagesFromGoogle/paper.jpg')
img_fastai = Image(pil2tensor(img_cv2,np.float32).div_(255))
#img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
print(type(img_fastai))
# Out:
# <class 'fastai.vision.image.Image'>

# %%
pred = learnModel.predict(img_fastai)
print(pred)
# Out:
# (Category tensor(3), tensor(3), tensor([3.0792e-03, 6.0461e-05, 2.2944e-05, 9.8929e-01, 7.5427e-03, 9.3423e-06]))

# %%
print(pred[2].shape)
pred[2]
# Out:
# torch.Size([6])
# tensor([3.0792e-03, 6.0461e-05, 2.2944e-05, 9.8929e-01, 7.5427e-03, 9.3423e-06])

# %%
dataclasses= ['كرتون', 'زجاج', 'معدن', 'ورق', 'بلاستيك', 'قمامة']

# %%
max_idxs = np.asarray(np.argmax(pred[2],axis=0))
max_idxs
# Out:
# array(3)

# %%
yhat = []
yhat.append(dataclasses[max_idxs])

# %%
yhat
# Out:
# ['ورق']

# %%
pred_path = Path('/content/drive/MyDrive/Recycle_Classification/' + '/TestImagesFromGoogle')

# %%
il = ImageList.from_folder(pred_path); 
il
# Out:
# ImageList (14 items)
# Image (3, 612, 612),Image (3, 224, 225),Image (3, 168, 300),Image (3, 187, 270),Image (3, 1280, 1920)
# Path: /content/drive/MyDrive/Recycle_Classification/TestImagesFromGoogle

# %%
for img in il:
   prediction = learnModel.predict(img)
   img.show(figsize=(7,5), title = str(prediction[0]))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
